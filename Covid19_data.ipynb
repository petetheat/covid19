# %%
from coronadata import getdata
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Johns Hopkins Data

# %%
file_path = r'../COVID-19/csse_covid_19_data/csse_covid_19_time_series'

# %%
data = getdata.DataLoader(file_path)

# %%
data.df.head()
# Out:
#                        Country/Region       Date  Cases confirmed  \
# Afghanistan_01/22/2020    Afghanistan 2020-01-22                0
# Afghanistan_01/23/2020    Afghanistan 2020-01-23                0
# Afghanistan_01/24/2020    Afghanistan 2020-01-24                0
# Afghanistan_01/25/2020    Afghanistan 2020-01-25                0
# Afghanistan_01/26/2020    Afghanistan 2020-01-26                0
#
#                         Cases deaths  Cases Recovered  Cases active
# Afghanistan_01/22/2020             0              0.0           0.0
# Afghanistan_01/23/2020             0              0.0           0.0
# Afghanistan_01/24/2020             0              0.0           0.0
# Afghanistan_01/25/2020             0              0.0           0.0
# Afghanistan_01/26/2020             0              0.0           0.0

# %%
data.plot('Germany')

# %%
data.plot('Italy')

# %%
data.plot('Spain')

# %%
data.plot('France')

# %% [markdown]
# # Robert Koch Institut Data

# %%
rki = getdata.get_rki()
# Out:
#   0%|                                                                                          | 0/582 [00:00<?, ?it/s]
# Querying data from RKI...
# 100%|████████████████████████████████████████████████████████████████████████████████| 582/582 [05:42<00:00,  1.70it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 583/583 [00:00<00:00, 38887.41it/s]
# Creating pandas dataframe...

# %%
rki.plot()
# Out:
# Index(['Date', 'IdBundesland', 'AnzahlFall', 'AnzahlTodesfall', 'ObjectId',
#        'NeuerFall', 'NeuerTodesfall', 'Refdatum', 'NeuGenesen',
#        'AnzahlGenesen', 'Cases confirmed', 'Cases deaths', 'Cases Recovered',
#        'Cases active', 'Region'],
#       dtype='object')

# %%
rki.plot(region='Bremen')
# Out:
# Index(['Region', 'Date', 'IdBundesland', 'Cases confirmed', 'Cases deaths',
#        'ObjectId', 'NeuerFall', 'NeuerTodesfall', 'Refdatum', 'NeuGenesen',
#        'Cases Recovered', 'Cases active'],
#       dtype='object')
